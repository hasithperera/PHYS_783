# %%
import numpy as np
import matplotlib.pyplot as plt

import pandas as pd

# %%
# file = 'data/run_1/landaudamp1.vp_energy'
file = '/Users/hasith/Projects/PHYS_783/src/data/run_1/landaudamp1.vp_energy'
  
data = np.loadtxt(file)

# %%
print(len(data))
print(np.shape(data))
# Out:
# 20001
# (20001, 36)

# %% [markdown]
# ## Plot direct outputs

# %%
for i in range(0,36):
    plt.figure()
    plt.plot(data[:,i])
    plt.title(i)
    
    

#plt.plot(data[:,2])
#plt.plot(data[:,4])
#plt.plot(data[:,5])
#plt.plot(data[:,2]-data[0,2])
#plt.plot(data[:,3]-data[0,3])
# Out:
# /var/folders/8f/c2gj1hw16vv143f6lc6wfxj00000gp/T/ipykernel_3913/4223554790.py:2: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   plt.figure()

# %% [markdown]
# ## Basic energy plots

# %%
plt.plot(data[:,2])
plt.plot(data[:,3]+data[:,4]+data[:,5])
plt.plot(data[:,5])
plt.plot(data[:,4])
plt.plot(data[:,3])

# %%
e_fld = data[:,3]-data[0,3]
plt.plot(e_fld,label='$E_\phi$') #ephi

e_part = data[:,4]-data[0,4]+data[:,5]-data[0,5]
plt.plot(e_part,label='efs(0)+efs(1)') #efs(0)
#plt.plot() #efs(1)

plt.plot(data[:,2]-data[0,2],label = '$E_{total}$')
plt.plot(e_fld+e_part,label = 'fld + par')

plt.legend()
# indx = 6
# plt.plot(data[:,indx]-data[0,indx]) #efsb(0)
# plt.plot(data[:,indx+1]-data[0,indx+1]) #efsb(1)

# indx = 8
# plt.plot(data[:,indx]-data[0,indx]) #efsb(0)
# plt.plot(data[:,indx+1]-data[0,indx+1]) #efsb(1)

# %%
indx = 10
plt.plot(data[:,indx]-data[0,indx]) #efsb(0)
plt.plot(data[:,indx+1]-data[0,indx+1]) #efsb(1)

indx = 4
plt.plot(data[:,indx]-data[0,indx],'o',markevery=.1) #efsb(0)
plt.plot(data[:,indx+1]-data[0,indx+1],'o',markevery=.1) #efsb(1)
